# %% [markdown]
# # Introduction

# %% [markdown]
# To start off, food security is defined as the physical and economic access to sufficient safe and nutritious food that meets a eprsons dietary needs and
# food preferences. Astoundingly, over [44 million people in the United States are food insecure](https://www.feedingamerica.org/hunger-in-america), with 1 in 5 children in the United States being food insecure. It is important to note that food insecurrity is prevalent in all communities, not just in lower income communities with less access to resources.

# %% [markdown]
# Making sure that all communities are food secure is incredibly important, and through this project, I will analyze how many socioeconomic factors might be connected to food security by looking at economic data, agricultural production data, and environmental data in tnadem with food security data.

# %% [markdown]
# style>
# [Hello](https://www.ers.usda.gov/topics/food-nutrition-assistance/food-security-in-the-u-s/)

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1656699aa3ae> in <cell line: 2>()
#       1 #Read excel file into a dataframe
# ----> 2 data_xlsx = pd.read_excel('GrainDemandProduction.xlsx', 'GrainDemandProduction', index_col=None)
#       3
#       4 #Replace all columns having spaces with underscores
#       5 data_xlsx.columns = [c.replace(' ', '_') for c in data_xlsx.columns]
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# ...

# %%
data = pd.read_csv("CornCostReturn.csv")

# %%
data.head(200)
# Out:
#     Commodity                   Category                       Item  \
# 0        Corn  Gross value of production     Primary product, grain
# 1        Corn  Gross value of production     Primary product, grain
# 2        Corn  Gross value of production     Primary product, grain
# 3        Corn  Gross value of production     Primary product, grain
# 4        Corn  Gross value of production     Primary product, grain
# ..        ...                        ...                        ...
# 195      Corn  Gross value of production     Primary product, grain
# 196      Corn  Gross value of production  Secondary product, silage
# 197      Corn  Gross value of production  Secondary product, silage
# 198      Corn  Gross value of production  Secondary product, silage
# 199      Corn  Gross value of production  Secondary product, silage
#
#                          Item2                     Units              Size  \
# ...

# %%
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    --------------------------------------- 250.0/250.0 kB 15.0 MB/s eta 0:00:00
# ...

# %%
# Define gradient descent algorithm
def grad_descent(X, y, T, alpha):
    m, n = X.shape  # m = #examples, n = #features
    theta = np.zeros(n, dtype=float)  # initialize parameters as floats
    f = np.zeros(T)  # track loss over time
    for i in range(T):
        # loss for current parameter vector theta
        f[i] = 0.5 * np.linalg.norm(np.dot(X, theta) - y) ** 2
        g = np.dot(X.T, np.dot(X, theta) - y)
        # step down the gradient
        theta = theta - alpha * g
    return theta, f

# Extract independent and dependent variables
X_train = train_set[["High", "Open", "Low"]].values.astype(float)
y_train = train_set["Close"].values.astype(float)

# Normalize the features
X_train = (X_train - X_train.mean(axis=0)) / X_train.std(axis=0)

# Add bias term to the independent variables
X_train = np.c_[np.ones(X_train.shape[0]), X_train]

# Set hyperparameters
T = 1000  # Number of iterations
alpha = 0.01  # Learning rate

# Train the model using gradient descent
weights, loss_history = grad_descent(X_train, y_train, T, alpha)

# List out weights and bias
print("Weights:")
print("Bias:", weights[0])
print("High:", weights[1])
print("Open:", weights[2])
print("Low:", weights[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3bc5d2a29ade> in <cell line: 15>()
#      13
#      14 # Extract independent and dependent variables
# ---> 15 X_train = train_set[["High", "Open", "Low"]].values.astype(float)
#      16 y_train = train_set["Close"].values.astype(float)
#      17
#
# NameError: name 'train_set' is not defined
